# %% [markdown]
# # Module IN PYTHON

# %% [markdown]
# ## A modules in python 	is simply a file containing python code (functions, classes or variables) that can be imported and used in other programs

# %% [markdown]
# ## 1.A module helps in code organization
# ## 2. It promotes reusability
# ## 3. It keeps the code clean and manageable

# %% [markdown]
# ## Numpy :-  module hepls with applying the scientific calculation on the array and we can store our data by consuming less space and we can apply the operation with our array a bit more faster as compared to those of the List
#
# ## we can do it in Numpy just because Numpy is having the collection of function and attributes which can help us to work effeciently eith the array

# %% [markdown]
# ## Pandas :- pandas we can use when we are going to work with the dataset for cleaning process, pre proceesing , EDA , analysis with Plotting as well

# %% [markdown]
# # 1. Math modules :- is going to be to used to perfoorm maths actions

# %%
import math
# sqrt is used to find the square root of a number 
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt

sqrt(16)
# Out:
# 4.0

# %%
from math import * # is used import all function inside the math modules
print(pi)
# Out:
# 3.141592653589793

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy

# %%
li = [[1,2,3,4,5,6]]
na = numpy.array(li)
print(type(na))
print(na)
# Out:
# <class 'numpy.ndarray'>
# [[1 2 3 4 5 6]]

# %% [markdown]
# ## i am trying to create my own Librabry and Module and in this library i want the function and the attributes to be created on my own

# %% [markdown]
# ## __init__.py is a file that has to be there inside the package folder and this __init__.py file helps us out in defining our packages and initializing their namespaces

# %% [markdown]
# ## __init__.py this file can remain empty as well and it's completely fine but this file has to be there when we will be creating our new packages into the package folder

# %%
from packagefolder.mathematics import addition

# %%
addition(3,5)
# Out:
# 8

# %%
from packagefolder.mathematics import *
division(2,0)
division(12,2)
# Out:
# 6.0

# %%
from packagefolder.subpackages.add import *

# %%
add(4,5,6)
# Out:
# 15
