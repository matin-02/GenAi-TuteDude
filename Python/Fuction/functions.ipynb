# %% [markdown]
# # Functions

# %% [markdown]
# A function is a block of code that perform the specific task.
# function helps in organizing code , Reusing code and improving readability

# %% [markdown]
#  Function are resuable and by that we means to say is we dont have to write the same piece of code again and again and this is sign of good programmer as we dont have to write same code again and along with that it can helps us out with the orginizing the code as well

# %% [markdown]
# # Syntax for function
#
# # def function_name(parameters):
# #	"Docstring "
# #	# Function Body
# #	return expression

# %% [markdown]
# # Why Function
# It increase Readability,Resuability and for organizing the code as well

# %%
# we are creating a function to see that how 
# the translation is going to be their from english to hindi language

def translator(English_text):
    """this function is going to be used for converting the english language into hindi language"""
    if English_text == "Hello" or English_text == "hello":
        print(f"the translation for {English_text} is Namaste  ")
    if English_text == "Help" or English_text == "help":
        print(f"the translation for {English_text} is Madad")

    if English_text == "Required" or English_text == "required":
        print(f"the translation for {English_text} id Aavashayak")

t = translator("help")
# Out:
# the translation for help is Madad

# %% [markdown]
# # For having the access to our function and to provide the input our fuction we can simply call the function

# %% [markdown]
# function call is just like calling the waitor in a restaurant where in just like we call the waitor and provide the input as the food item and then waitor provide us with the food itself , like in a similiar way we can call a function as well and can provide the input and can get required output after calling the function only

# %%
# For having the access to our function and to provide the input our fuction we can simply call the function 
t1 = input("enter a english word ")
t = translator(t1)

# %%
## calling the function --> Mention the name of the function and then provide input
english_input = input("Enter your english word ")
translator(english_input)

# %%
# Function to convert the English into Hindi

def translator_return(english_text):
    if english_text == "Hello" or english_text == "hello":
        Hindi_word = "Namaste"

    elif english_text == "help" or english_text == "Help":
        Hindi_word = "Madad"

    elif english_text == "Required" or english_text == "required":
        Hindi_word == "Aavashayak"

    return Hindi_word

# %%
english_input = input("Enter your English : ")
hindi_output = translator_return(english_input)
print(hindi_output)
# Out:
# Madad

# %% [markdown]
# # Difference Between the parameter and arguments
#
# ## parameters is the input that we used to have when we define the function
# ## arguments is the input that we used to pass when we call the function
